# %% [markdown]
# ![<AIfc align="center">](https://drive.google.com/uc?id=1CG1uuDgnNxqcrkq-jbffw5Hn4SfSiDQE)

# %% [markdown]
# **Owner's Name**: Prasanta Kundu

# %% [markdown]
# # Contributer's Profiles
#
# - K Harini ( [Linkedin]() , [Github]() )
# - Aravind C J ( [Linkedin]() , [Github]() )
# - Megha Mhaske ( [Linkedin]() , [Github]() )
# - Prasanta Kundu ( [Linkedin]() , [Github]() )

# %% [markdown]
# # Team & Contact Info

# %% [markdown]
# Team Name | Member's Name | Role | Mobile No. | Email Id
# --- | --- | --- | --- | ---
#   | K Harini | TL | --- | ---
# Starter | Aravind C J | TM | --- | ---
#  | Megha Mhaske | TM | 9766945700 | meghanmhaske@gmail.com
#  | Prasanta Kundu | Mentor | 9890228513 | pkundu25@gmail.com

# %% [markdown]
# # Detailed Approach #

# %% [markdown]
# ### 1. Problem Statement

# %% [markdown]
# *Breifly describe the business problem that needs to be addressed as part of the project*
#
# **Business Context:**
#
# Marketers and Customer
# Relationship Management (CRM) specialists have access to rich
# data on consumer behaviour. The current challenge is effective
# utilisation of these data in CRM processes and selection of
# appropriate data analytics techniques which
# help find hidden patterns in data. It is a useful tool for sales managers to extract the data insights in CRM process.
# There are different analytical tools and techciques that are available for sales managers for continuous
# improvement of CRM processes. Analytical CRM has gained momentum in recent times
# due to improvement of computing technologies. In the
# era of rapidly changing, globalised economies, and highly
# competitive markets, transformation from a product-centric
# focus to a more customer-centric view is, therefore, required. Customers
# expect personalised products and services because they know
# that companies have data about them and the opportunity exists
# to provide customisation.
#
# This can be achieved by using The data mining (DM) techniques can help sales and Marketing teams to
# find the hidden and unknown customer information from
# customer data and, thus, achieve effective CRM.
#
# Demographic, socioeconomic or geographic characteristics
# of the customers are the traditionally and widely used variables
# for the customer analysis. Customer intelligence data mining
# models may be the most powerful and simplest technique for generating leads in most
# of the organizations. Data analytics, supported by CRM, can be used throughout the
# organisation, from forecasting customer behaviour and
# purchasing patterns to identifying trends in sales activities.
# Data analytics needs to be used to form responses to real time
# shifts in customer actions and behaviour. As usage matured, requirements to
# include predictive analytics, event-driven alerts, and
# operational decision support have become the norm.
#
# **Business Problem:**
#
# To be able to generate effective and successful lead, organizations must have ability to manage the customer and sales related data and information in a systematic way. Sales and accounts teams must be able to leverage various BI tools and techniques to derive data insights across gerographies and industry verticals within the organization.
#
# It is, therefore, necessary to analyse the data around CRM process which will help business to optimize revenue and profitability while maintaining a healthy sales pipeline.

# %% [markdown]
# ### 2. Dataset###

# %% [markdown]
# The CRM dataset is obtained from a public domain and is made available in Google drive shared folder. Please click [here](https://drive.google.com/open?id=1cQUYby03CyF7r1XAc9tMQsMpod62rR8R) to access to the dataset.
#
# The dataset comprises of 5 .csv files.
#
# Each of the files contains multiple different column features/data attributes.
#
# Our task would be to carry out our Exploratory Data Analysis (EDA) and extact the useful business intelligence for the Sales and marketing teams for sustained business development.
#
#
#
# **Features**:
#
# 1. clicks.csv – Contains 3 columns as follows:
#
# Created_On: Date when the sales order is created in CRM system
#
# Source: Channel through which sale leads are generated
#
# Industry: Industry vertical/sector
#
# 2. products_.csv – Contains 2 columns as follows:
#
# Product: Name of products being offered
#
# Sales_Price: Offer price of a product in a given currency
#
# 3. accounts.csv – Contains 3 columns as follows:
#
# Account: Name of the account within the organization
#
# Revenue: Total value of sales within an account in a given currency
#
# Employees: Count of employees working in a given account
#
# 4. sales-pipeline.csv – Contains 8 columns as follows:
#
# Account: Name of the account within the organization
#
# Opportunity_ID: Identifier assigned against the sales opportunity
#
# Sales_Agent: Name of the agent responsible for creating the opportunity
#
# Deal_Stage: Current status of the deal
#
# Product: Name of products being offered
#
# Close_Date: Date by when the sales deal is closed
#
# Close_Value: Value of sales when the deal is closed
#
# Created_On: Date when the sales order is created in CRM system
#
# 5. sales-teams.csv – Contains 3 columns as follows:
#
# Sales_Agent: Name of the agent responsible for creating the opportunity
#
# Manager: Name of the Manager representing the Sales Agent
#
# Regional_Office: Location of the regional office the Sales Agent operates from

# %% [markdown]
# ###3. Design Thinking

# %% [markdown]
# Brainstorm the resources and bring out your thought process here as to how we can address the business problem. We may have mutiple differenent ideas and proposed solutions. Let's write down those in the form of workflows.

# %% [markdown]
# ### 4. Literature Survey

# %% [markdown]
# Collect all relevant information resources and URLs addressing similar problems and their associated use cases. List it down here
#
# - https://towardsdatascience.com/how-to-deploy-your-data-science-as-web-apps-easily-with-python-955dd462a9b5 (*sample*)
# - https://www.techedgegroup.com/blog/data-science-process-problem-statement-definition
# - https://openviewpartners.com/blog/how-to-conduct-crm-data-analysis/#.Xs4dzTozbIU

# %% [markdown]
# ### 5. Exploratory Data Analysis (EDA)

# %% [markdown]
# - Understand the types of data
# - List down the business questions to be answered to derive data insights
# - Perform descriptive data anaylysis (statistical)
# - Data pre-processing / cleansing both for numerical and categorical variables
# - Visualize the data (Try to use plotly for interactive visualizations)
# - Describe the approach being applied and findings for the respective business questions
#
#
#
# Add Colab link here:
# <Link>

# %% [markdown]
# ###6.  Conclusions

# %% [markdown]
# Summarize your findings in terms of actionable insights (bulletted)
#
#
# *   List item
# *   List item

# %% [markdown]
# ###7. Creating files and documentation

# %% [markdown]
# - Create notebook files with appropriate nomenclature and version control. Later we will look to deploy the results as an App either in heroku or in the Cloud.
#
# - Add Colab link here:
#   - Link <Link>

# %% [markdown]
# # Project Plan

# %% [markdown]
# This would involve the following:
# List down all activities alongwith timeline eg.,
#
# collection of reference resources,
# list of tasks to be performed for EDA,
# list of tasks to be performed for Model build and evaluation etc.
#
# Each of the activities will have start date and end date. Monitor and track the progress the tasks/activities until project closure.
#
# Click [here](https://drive.google.com/open?id=1nOT5uwtsiQuK0qzQwCw751l74tJ1Mtqq) to access Project Plan Tracker and Gantt Chart.
